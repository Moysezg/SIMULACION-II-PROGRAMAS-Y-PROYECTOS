# %% [markdown]
# <a href="https://colab.research.google.com/github/Moysezg/Bondad-de-Ajuste-de-Chi-cuadrado/blob/main/Ejercicio_2_Serpientes_y_escaleras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista=[]
lanzamientos=0
suma=0
promedio=0
import random
for i in range(1,10000):
  while suma<20:
    n = (int(random.uniform(1, 7)))
    suma=suma+n
    #print("dado:",n)
    if suma==3:
        suma=suma+8
        #print("sube a 11")
    if suma==15:
        suma=suma+4
        #print("sube a 19")
    if suma==13:
        suma=suma-9
        #print("baja a 4")
    if suma==17:
        suma==suma-7 
        #print("baja a 10")
    #print("estas en la casilla:",suma)
    lanzamientos=lanzamientos+1
  #print("Juego",i,"Numero de lanzamientos:",lanzamientos)
  promedio=lanzamientos+promedio
  suma=0
  lanzamientos=0
  promedioa=round(promedio/i,5)
  lista.append(promedioa)
#print(lista)

import matplotlib.pyplot as plt

plt.plot(lista)   # Dibuja el gráfico
plt.title("Serpientes y escaleras")   # Establece el título del gráfico
plt.xlabel("juegos")   # Establece el título del eje x
plt.ylabel("lanzamientos")   # Establece el título del eje y
#print(lista_bp)
# Out:
# Text(0, 0.5, 'lanzamientos')

# %%
lista=[]
lanzamientos=0
suma=0
promedio=0
import random
while suma<20:
    n = (int(random.uniform(1, 7)))
    suma=suma+n
    print("Caiste:",n)
    if suma==3:
        suma=suma+8
        print("caiste en escalera, subes a 11")
    if suma==15:
        suma=suma+4
        print("caiste en escalera, subes a 19")
    if suma==13:
        suma=suma-9
        print("caiste en Serpiente, bajas a 4")
    if suma==17:
        suma==suma-7 
        print("caiste en serpiente bajas a 10")
    print("estas en la casilla:",suma)
    lanzamientos=lanzamientos+1
print("Terminaste, Numero de lanzamientos:",lanzamientos)
# Out:
# Caiste: 4
# estas en la casilla: 4
# Caiste: 1
# estas en la casilla: 5
# Caiste: 2
# estas en la casilla: 7
# Caiste: 2
# estas en la casilla: 9
# Caiste: 4
# caiste en Serpiente, bajas a 4
# estas en la casilla: 4
# Caiste: 4
# estas en la casilla: 8
# Caiste: 4
# estas en la casilla: 12
# Caiste: 4
# estas en la casilla: 16
# Caiste: 5
# estas en la casilla: 21
# Terminaste, Numero de lanzamientos: 9
